# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
from io import StringIO
import re

# %%
# Fetch Disease-symptoms knowledge database
url = 'https://people.dbmi.columbia.edu/~friedma/Projects/DiseaseSymptomKB/index.html'

# Request page content
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    tables = soup.find_all('table', {'class': 'MsoTableWeb3'})

    if len(tables) > 0:
        table = tables[0]
        rows = table.find_all('tr')

        # Extract header from the first row
        headers = [th.get_text(strip=True) for th in rows[0].find_all(['th', 'td'])]

        # Extract all subsequent rows into a list of lists
        data = []
        for row in rows[1:]:
            cols = row.find_all('td')
            cols = [col.get_text(strip=True) for col in cols]
            if cols:
                data.append(cols)

        # Create DataFrame
        df = pd.DataFrame(data, columns=headers)

        # Print preview
        print("✅ Table scraped successfully:")


        # Now df holds your table as a DataFrame and you can continue using it
    else:
        print("❌ No table with class 'MsoTableWeb3' found.")
else:
    print(f"❌ Failed to fetch the page. Status code: {response.status_code}")
# Out:
# ✅ Table scraped successfully:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1866 entries, 0 to 1865
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Disease                        1866 non-null   object
#  1   Count of Disease
#   Occurrence  1866 non-null   object
#  2   Symptom                        1866 non-null   object
# dtypes: object(3)
# memory usage: 43.9+ KB

# %%
df.head()
# Out:
#                                  Disease Count of Disease\n  Occurrence  \
# 0  UMLS:C0020538_hypertensive\n  disease                           3363
# 1
# 2
# 3
# 4
#
#                                 Symptom
# 0           UMLS:C0008031_pain\n  chest
# 1  UMLS:C0392680_shortness\n  of breath
# 2               UMLS:C0012833_dizziness
# 3                UMLS:C0004093_asthenia
# 4                    UMLS:C0085639_fall

# %%
import pandas as pd
import re

# Check if 'Disease' column exists
if 'Disease' in df.columns:
    # Step 1: Filter out rows containing actual diseases
    disease_rows = df[df['Disease'].notna() & df['Disease'].str.startswith('UMLS:')]

    # Step 2: Extract diseaseID and Dname from valid entries
    disease_set = set()

    for row in disease_rows['Disease']:
        entries = str(row).split('^')  # Split in case of multiple diseases

        for entry in entries:
            entry = entry.strip()
            match = re.match(r'UMLS:(C\d{6})_(.+)', entry)
            if match:
                disease_id = match.group(1)
                dname = match.group(2).replace('_', ' ').strip().lower()
                disease_set.add((disease_id, dname))
            else:
                # Log unmatched entries for debugging
                print(f"Unmatched entry: {entry}")

    # Step 3: Convert to DataFrame
    if disease_set:
        disease_records = [{'diseaseID': did, 'Dname': dname} for did, dname in sorted(disease_set)]
        diseases_df = pd.DataFrame(disease_records)
        
        # Final Output
        print(f"✅ diseases_df created with {len(diseases_df)} records:")
        print(diseases_df.head())
    else:
        print("No valid disease entries found.")
else:
    print("The 'Disease' column is missing!")
# Out:
# Unmatched entry: UMLS:C0020538_hypertensive
#   disease
# Unmatched entry: UMLS:C0011847_diabetes
# Unmatched entry: UMLS:C0011570_depression
#   mental
# Unmatched entry: UMLS:C0011581_depressive disorder
# Unmatched entry: UMLS:C0010054_coronary
#   arteriosclerosis
# Unmatched entry: UMLS:C0010068_coronary heart disease
# Unmatched entry: UMLS:C0032285_pneumonia
# Unmatched entry: UMLS:C0018802_failure
#   heart congestive
# Unmatched entry: UMLS:C0038454_accidentcerebrovascular
# Unmatched entry: UMLS:C0004096_asthma
# Unmatched entry: UMLS:C0027051_myocardial
#   infarction
# Unmatched entry: UMLS:C0020443_hypercholesterolemia
# Unmatched entry: UMLS:C0021311_infection
# Unmatched entry: UMLS:C0042029_infection
#   urinary tract
# Unmatched entry: UMLS:C0002871_anemia
# Unmatched entry: UMLS:C0024117_chronic
#   obstructive airway disease
# Unmatched entry: UMLS:C0497327_dementia
# Unmatched entry: UMLS:C1565489_insufficiency
#   renal
# Unmatched entry: UMLS:C0009676_confusion
# Unmatched entry: UMLS:C0029408_degenerativepolyarthritis
# Unmatched entry: UMLS:C0020676_hypothyroidism
# Unmatched entry: UMLS:C0700613_anxiety
#   state
# Unmatched entry: UMLS:C0006826_malignant
#   neoplasms
# Unmatched entry: UMLS:C1306459_primary malignant neoplasm
# Unmatched entry: UMLS:C0001175_acquiredimmuno-deficiency
#   syndrome
# Unmatched entry: UMLS:C0019682_HIV
# Unmatched entry: UMLS:C0019693_hiv infections
# Unmatched entry: UMLS:C0007642_cellulitis
# Unmatched entry: UMLS:C0017168_gastroesophageal
#   reflux disease
# Unmatched entry: UMLS:C0036690_septicemia
# Unmatched entry: UMLS:C0243026_systemic
#   infection
# Unmatched entry: UMLS:C1090821_sepsis (invertebrate)
# Unmatched entry: UMLS:C0149871_deep
#   vein thrombosis
# Unmatched entry: UMLS:C0011175_dehydration
# Unmatched entry: UMLS:C0027651_neoplasm
# Unmatched entry: UMLS:C0034065_embolism
#   pulmonary
# Unmatched entry: UMLS:C0014544_epilepsy
# Unmatched entry: UMLS:C0878544_cardiomyopathy
# Unmatched entry: UMLS:C0022661_chronic
#   kidney failure
# Unmatched entry: UMLS:C0007097_carcinoma
# Unmatched entry: UMLS:C0019196_hepatitis
#   C
# Unmatched entry: UMLS:C0085096_peripheral
#   vascular disease
# Unmatched entry: UMLS:C0033975_psychotic
#   disorder
# Unmatched entry: UMLS:C0020473_hyperlipidemia
# Unmatched entry: UMLS:C0005586_bipolar
#   disorder
# Unmatched entry: UMLS:C0028754_obesity
# Unmatched entry: UMLS:C0022116_ischemia
# Unmatched entry: UMLS:C1623038_cirrhosis
# Unmatched entry: UMLS:C0015230_exanthema
# Unmatched entry: UMLS:C0005001_benign
#   prostatic hypertrophy
# Unmatched entry: UMLS:C0022660_kidney
#   failure acute
# Unmatched entry: UMLS:C0026266_mitral
#   valve insufficiency
# Unmatched entry: UMLS:C0003864_arthritis
# Unmatched entry: UMLS:C0006277_bronchitis
# Unmatched entry: UMLS:C0018989_hemiparesis
# Unmatched entry: UMLS:C0029456_osteoporosis
# Unmatched entry: UMLS:C0007787_transient
#   ischemic attack
# Unmatched entry: UMLS:C0001418_adenocarcinoma
# Unmatched entry: UMLS:C1456784_paranoia
# Unmatched entry: UMLS:C0030305_pancreatitis
# Unmatched entry: UMLS:C0021167_incontinence
# Unmatched entry: UMLS:C0013405_paroxysmaldyspnea
# Unmatched entry: UMLS:C0019270_hernia
# Unmatched entry: UMLS:C0376358_malignant
#   neoplasm of prostate
# Unmatched entry: UMLS:C0600139_carcinoma prostate
# Unmatched entry: UMLS:C0034063_edema
#   pulmonary
# Unmatched entry: UMLS:C0024228_lymphatic
#   diseases
# Unmatched entry: UMLS:C0003507_stenosis
#   aortic valve
# Unmatched entry: UMLS:C0006142_malignant
#   neoplasm of breast
# Unmatched entry: UMLS:C0678222_carcinoma breast
# Unmatched entry: UMLS:C0036341_schizophrenia
# Unmatched entry: UMLS:C0012813_diverticulitis
# Unmatched entry: UMLS:C0546817_overload
#   fluid
# Unmatched entry: UMLS:C0030920_ulcer
#   peptic
# Unmatched entry: UMLS:C0029443_osteomyelitis
# Unmatched entry: UMLS:C0017152_gastritis
# Unmatched entry: UMLS:C0004610_bacteremia
# Unmatched entry: UMLS:C0035078_failure
#   kidney
# Unmatched entry: UMLS:C0002895_sickle
#   cell anemia
# Unmatched entry: UMLS:C0018801_failure
#   heart
# Unmatched entry: UMLS:C0041912_upper
#   respiratory infection
# Unmatched entry: UMLS:C0019158_hepatitis
# Unmatched entry: UMLS:C0020542_hypertension
#   pulmonary
# Unmatched entry: UMLS:C0011168_deglutition
#   disorder
# Unmatched entry: UMLS:C0018099_gout
# Unmatched entry: UMLS:C0040034_thrombocytopaenia
# Unmatched entry: UMLS:C0020615_hypoglycemia
# Unmatched entry: UMLS:C0032290_pneumonia
#   aspiration
# Unmatched entry: UMLS:C0009319_colitis
# Unmatched entry: UMLS:C1510475_diverticulosis
# Unmatched entry: UMLS:C0038663_suicide
#   attempt
# Unmatched entry: UMLS:C0032305_Pneumocystiscariniipneumonia
# Unmatched entry: UMLS:C0019163_hepatitis
#   B
# Unmatched entry: UMLS:C0030567_parkinson
#   disease
# Unmatched entry: UMLS:C0024299_lymphoma
# Unmatched entry: UMLS:C0020456_hyperglycemia
# Unmatched entry: UMLS:C0085584_encephalopathy
# Unmatched entry: UMLS:C0040961_tricuspid
#   valve insufficiency
# Unmatched entry: UMLS:C0002395_Alzheimer's
#   disease
# Unmatched entry: UMLS:C0006840_candidiasis
# Unmatched entry: UMLS:C0006849_oralcandidiasis
# Unmatched entry: UMLS:C0442874_neuropathy
# Unmatched entry: UMLS:C0022658_kidney
#   disease
# Unmatched entry: UMLS:C0023267_fibroid
#   tumor
# Unmatched entry: UMLS:C0017601_glaucoma
# Unmatched entry: UMLS:C0027627_neoplasm
#   metastasis
# Unmatched entry: UMLS:C0007102_malignant
#   tumor of colon
# Unmatched entry: UMLS:C0699790_carcinoma colon
# Unmatched entry: UMLS:C0011880_ketoacidosis
#   diabetic
# Unmatched entry: UMLS:C0014549_tonic-clonic
#   epilepsy
# Unmatched entry: UMLS:C0494475_tonic-clonic seizures
# Unmatched entry: UMLS:C0006826_malignantneoplasms
# Unmatched entry: UMLS:C1145670_respiratory
#   failure
# Unmatched entry: UMLS:C0025202_melanoma
# Unmatched entry: UMLS:C0017160_gastroenteritis
# Unmatched entry: UMLS:C0242379_malignant
#   neoplasm of lung
# Unmatched entry: UMLS:C0684249_carcinoma of lung
# Unmatched entry: UMLS:C0024713_manic
#   disorder
# Unmatched entry: UMLS:C0031212_personality
#   disorder
# Unmatched entry: UMLS:C0019204_primary
#   carcinoma of the liver cells
# Unmatched entry: UMLS:C0034067_emphysema
#   pulmonary
# Unmatched entry: UMLS:C0019112_hemorrhoids
# Unmatched entry: UMLS:C0006266_spasm
#   bronchial
# Unmatched entry: UMLS:C0003537_aphasia
# Unmatched entry: UMLS:C0028756_obesity
#   morbid
# Unmatched entry: UMLS:C0034186_pyelonephritis
# Unmatched entry: UMLS:C0014118_endocarditis
# Unmatched entry: UMLS:C0031039_effusion
#   pericardial
# Unmatched entry: UMLS:C1253937_pericardial effusion body substance
# Unmatched entry: UMLS:C0001973_chronic
#   alcoholic intoxication
# Unmatched entry: UMLS:C0032326_pneumothorax
# Unmatched entry: UMLS:C0011206_delirium
# Unmatched entry: UMLS:C0027947_neutropenia
# Unmatched entry: UMLS:C0020433_hyperbilirubinemia
# Unmatched entry: UMLS:C0021400_influenza
# Unmatched entry: UMLS:C0439857_dependence
# Unmatched entry: UMLS:C0087086_thrombus
# Unmatched entry: UMLS:C0008325_cholecystitis
# Unmatched entry: UMLS:C0019291_herniahiatal
# Unmatched entry: UMLS:C0149931_migraine
#   disorders
# Unmatched entry: UMLS:C0030312_pancytopenia
# Unmatched entry: UMLS:C0008350_cholelithiasis
# Unmatched entry: UMLS:C0242216_biliary
#   calculus
# Unmatched entry: UMLS:C0039239_tachycardia
#   sinus
# Unmatched entry: UMLS:C1258215_ileus
# Unmatched entry: UMLS:C0001511_adhesion
# Unmatched entry: UMLS:C0011253_delusion
# Unmatched entry: UMLS:C0233472_affect
#   labile
# Unmatched entry: UMLS:C0011127_decubitus
#   ulcer
# No valid disease entries found.
